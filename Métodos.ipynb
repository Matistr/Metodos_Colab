# %% [markdown]
# <a href="https://colab.research.google.com/github/Matistr/Metodos_Colab/blob/main/M%C3%A9todos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clase 1 Métodos**

# %%
import pandas as pd #libreria pandas nos permite trabajar con bases de datos
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9bdf60cf-8bef-43cb-853f-d2bcaa9b9222" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bdf60cf-8bef-43cb-853f-d2bcaa9b9222">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('datos_depresion1.xlsx')
df.head()
# Out:
#    Age Marital Status Employment Status    Income Alcohol Consumption  \
# 0   31        Married        Unemployed   2626567            Moderate
# 1   55        Married          Employed   4271036                High
# 2   78        Widowed          Employed  12533279                 Low
# 3   58       Divorced        Unemployed    999278            Moderate
# 4   18         Single        Unemployed    859508                 Low
#
#   History of Mental Illness
# 0                       Yes
# 1                       Yes
# 2                        No
# 3                        No
# 4                       Yes

# %%
df.info() #entrega informacion de las columnas del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        586 non-null    int64
#  1   Marital Status             586 non-null    object
#  2   Employment Status          586 non-null    object
#  3   Income                     586 non-null    int64
#  4   Alcohol Consumption        586 non-null    object
#  5   History of Mental Illness  586 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 27.6+ KB

# %%
df.iloc[0:15] #iloc[num1:num2] la funcion extrae de la fila num1 hasta la num2
# Out:
#     Age Marital Status Employment Status    Income Alcohol Consumption  \
# 0    31        Married        Unemployed   2626567            Moderate
# 1    55        Married          Employed   4271036                High
# 2    78        Widowed          Employed  12533279                 Low
# 3    58       Divorced        Unemployed    999278            Moderate
# 4    18         Single        Unemployed    859508                 Low
# 5    20         Single          Employed   4444891                 Low
# 6    60        Widowed        Unemployed   2256547            Moderate
# 7    31         Single          Employed   3960818            Moderate
# 8    50       Divorced          Employed   9336007            Moderate
# 9    77        Married          Employed   7759784                 Low
# 10   70        Married        Unemployed   2852897            Moderate
# 11   59        Married          Employed   6122516            Moderate
# ...

# %%
df.iloc[54:58]
# Out:
#     Age Marital Status Employment Status   Income Alcohol Consumption  \
# 54   35        Married          Employed  9347926                High
# 55   56        Widowed          Employed  4134479                 Low
# 56   38        Married        Unemployed  1718024            Moderate
# 57   61        Widowed        Unemployed   820148                 Low
#
#    History of Mental Illness
# 54                        No
# 55                        No
# 56                       Yes
# 57                        No

# %%
df['History of Mental Illness']
# Out:
# 0      Yes
# 1      Yes
# 2       No
# 3       No
# 4      Yes
#       ...
# 581     No
# 582    Yes
# 583     No
# 584     No
# 585    Yes
# Name: History of Mental Illness, Length: 586, dtype: object

# %%
df['History of Mental Illness'].iloc[0:5]
# Out:
# 0    Yes
# 1    Yes
# 2     No
# 3     No
# 4    Yes
# Name: History of Mental Illness, dtype: object

# %%
df['History of Mental Illness'].value_counts() #la funcion nos devuelve  la frecuencia de cada variable
# Out:
# History of Mental Illness
# No     411
# Yes    175
# Name: count, dtype: int64

# %% [markdown]
# Definir DF compuesto por los individuos que ganan mas de 1 millon y menos de 1.5 millones

# %%
sol=df[(df['Income']>1000000)&(df['Income']<1500000)]

# %%
print(f'La cantidad de individuos que ganan entre 1 y 1.5 millones son {len(sol)}')
# Out:
# La cantidad de individuos que ganan entre 1 y 1.5 millones son 36

# %%
#renombrar columnas df
df.rename(columns={'Age':'Edad',
                   'Marital Status':'Estado Civil',
                   'Employment Status':'Estado Laboral',
                   'Income':'Ingresos',
                   'Alcohol Consumption':'Consumo de Alcohol',
                   'History of Mental Illness':'Depresion'})
# Out:
#      Edad Estado Civil Estado Laboral  Ingresos Consumo de Alcohol Depresion
# 0      31      Married     Unemployed   2626567           Moderate       Yes
# 1      55      Married       Employed   4271036               High       Yes
# 2      78      Widowed       Employed  12533279                Low        No
# 3      58     Divorced     Unemployed    999278           Moderate        No
# 4      18       Single     Unemployed    859508                Low       Yes
# ..    ...          ...            ...       ...                ...       ...
# 581    20       Single       Employed   4385572                Low        No
# 582    34      Married       Employed   3802425           Moderate       Yes
# 583    48      Widowed     Unemployed   1401616           Moderate        No
# 584    56      Widowed       Employed   1028937                Low        No
# 585    72      Widowed     Unemployed    215482           Moderate       Yes
#
# [586 rows x 6 columns]

# %% [markdown]
# # **Clase 2**

# %%
import pandas as pd #nos permite trabajar con bases de datos
import numpy as np #permite realizar operaciones con vectores y matrices
import matplotlib.pyplot as plt #nos permite graficar en 2D

# %%
datos={'estatura':[1.55,1.61,1.9,1.85,1.78,1.59,1.89,2.02],
       'peso':[65,89,78,101,78,65,89,100]}
df=pd.DataFrame(datos)
peso_total=df['peso'].sum()
print(f'El peso total es: {peso_total}')
# Out:
# El peso total es: 665

# %%
print('Funcion Logaritmo')
x=np.linspace(0.1,np.e,100) #linspace(punto inicial, punto final, numero de particiones)
f=np.log(x)
plt.plot(x,f,color='purple')
plt.title('Grafica de la funcion Logaritmo')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()
# Out:
# Funcion Logaritmo

# %%
#aplicar la funcion logaritmo a la columna peso:
def log(x): #definimos logaritmo
  return np.log(x)
df1=df['peso'].apply(log)
print(df1)
# Out:
# 0    1.428968
# 1    1.501549
# 2    1.471717
# 3    1.529338
# 4    1.471717
# 5    1.428968
# 6    1.501549
# 7    1.527180
# Name: peso, dtype: float64

# %%
#graficar la funcion tangente:
x1=np.linspace(0,8*np.pi,100)
f1=np.tan(x1)
plt.plot(x1,f1,color='black')
plt.title('Grafica de la funcion tan(x)')
plt.xlabel('x')
plt.ylabel('tan(x)')
plt.show()

# %%
#graficar la funcion seno:
f2=np.sin(x1)
plt.plot(x1,f2,color='red')
plt.title('Grafica de la funcion sen(x)')
plt.xlabel('x')
plt.ylabel('sen(x)')
plt.show()

# %%
#graficar la funcion coseno:
x=np.linspace(-np.pi,np.pi,100)
f=np.cos(x)
plt.plot(x,f,color='darkgreen')
plt.title('Grafica de la funcion cos(x)')
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
print('Graficar las funciones cos(x) y x^2-2x+2')
fig,ax=plt.subplots(2,1) #.subplots(n filas, n columnas)
x1=np.linspace(0.001,8*np.pi,100)
f1=np.cos(x1)
ax[0].plot(x1,f1,color='black')
ax[0].set_title('Grafica de la funcion cos(x)')

f2=x1**2-2*x1+2
ax[1].plot(x1,f2,color='black')
ax[1].set_title('Grafica de la funcion x^2-2x+2')

from google.colab import files
plt.savefig('graficas.jpg')
files.download('graficas.jpg')

plt.show()
# Out:
# Graficar las funciones cos(x) y x^2-2x+2

# %% [markdown]
# # Clase 3

# %%
fig,ax=plt.subplots(2,2)
f3=x1**5-3*x1**2
f4=np.log(x1**2)
f5=np.cos(x1**2)
f6=np.tan(x1**2)-1

ax[0,0].plot(x1,f3,color='blue')
ax[0,0].set_title('Grafica de la funcion x^5-3x^2')
ax[0,0].set_ylabel('f(x)')

ax[0,1].plot(x1,f4,color='black')
ax[0,1].set_title('Grafica de la funcion log(x^2)')

ax[1,0].plot(x1,f5,color='red')

ax[1,1].plot(x1,f6,color='purple')

from google.colab import files
plt.savefig('4graficas.pdf')
files.download('4graficas.pdf')

plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2b78c31e-7633-41c0-8f63-2115a2b7a277" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b78c31e-7633-41c0-8f63-2115a2b7a277">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_excel('datos_depresion1.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        586 non-null    int64
#  1   Marital Status             586 non-null    object
#  2   Employment Status          586 non-null    object
#  3   Income                     586 non-null    int64
#  4   Alcohol Consumption        586 non-null    object
#  5   History of Mental Illness  586 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 27.6+ KB

# %%
media=np.mean(df['Income'])
print(f'El sueldo medio de los individuos es: {round(media)}') #round redondea al enrtero mas cercano
print(f'La mediana de los ingresos es: {media:.2f}') #.nf considera n cifras decimales
# Out:
# El sueldo medio de los individuos es: 4773286
# La mediana de los ingresos es: 4773286.47

# %%
grupo=df.groupby(['Marital Status'])
grupo.get_group('Single')
# Out:
#      Age Marital Status Employment Status   Income Alcohol Consumption  \
# 4     18         Single        Unemployed   859508                 Low
# 5     20         Single          Employed  4444891                 Low
# 7     31         Single          Employed  3960818            Moderate
# 16    25         Single          Employed   908158                High
# 22    28         Single        Unemployed  2465161            Moderate
# ..   ...            ...               ...      ...                 ...
# 565   23         Single          Employed  9646813            Moderate
# 575   18         Single          Employed  3246563                High
# 578   23         Single          Employed  2645287                 Low
# 579   21         Single          Employed  3705757                 Low
# 581   20         Single          Employed  4385572                 Low
#
#     History of Mental Illness
# 4                         Yes
# 5                          No
# ...
